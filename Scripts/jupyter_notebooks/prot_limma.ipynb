# %%
import pandas as pd

# %%
S3421 = pd.read_csv('S3421_LM10C_analysis_result.csv', sep=',').drop('Unnamed: 0', axis=1)
S3421
# Out:
#                comparison    Entry.Name     logFC    AveExpr          t  \
# 0     exp_phase-lag_phase  A7V2T1_BACUC  1.082261  24.690309  59.528083
# 1     exp_phase-lag_phase  A7V2S8_BACUC  1.185927  21.553105  57.217744
# 2     exp_phase-lag_phase  A7VAE7_BACUC  0.916274  27.880119  51.463885
# 3     exp_phase-lag_phase  A7V4X7_BACUC -0.996023  22.753882 -50.009654
# 4     exp_phase-lag_phase  A7V487_BACUC  0.944287  29.586144  49.441177
# ...                   ...           ...       ...        ...        ...
# 7261  lag_phase-sta_phase  A7V9Z5_BACUC  0.007991  21.407549   0.073013
# 7262  lag_phase-sta_phase  A7V279_BACUC  0.001555  22.850305   0.070677
# 7263  lag_phase-sta_phase  A7V357_BACUC -0.001163  28.416902  -0.047264
# 7264  lag_phase-sta_phase  A7VAC0_BACUC -0.000793  19.735774  -0.035631
# 7265  lag_phase-sta_phase  A7V6N5_BACUC  0.001329  23.122828   0.025473
#
#            P.Value     adj.P.Val          B     hit          Gene  \
# ...

# %%
S3421[(abs(S3421.logFC) > 1.5) & (S3421['adj.P.Val'] < 0.05)]
# Out:
#                comparison    Entry.Name     logFC    AveExpr           t  \
# 8     exp_phase-lag_phase  A7V4Y1_BACUC -1.512108  24.925536  -45.816066
# 268   exp_phase-lag_phase  A7VA23_BACUC  1.519338  25.350116   13.876598
# 2422  exp_phase-sta_phase  A7UYG2_BACUC -1.821279  25.726192 -105.830913
# 2423  exp_phase-sta_phase  A7UZN6_BACUC -1.901213  23.618266  -95.965657
# 2426  exp_phase-sta_phase  A7V205_BACUC -1.511899  24.226039  -90.604453
# ...                   ...           ...       ...        ...         ...
# 6243  lag_phase-sta_phase  A7VA23_BACUC -1.547812  25.350116  -14.136661
# 6250  lag_phase-sta_phase  A7V869_BACUC -1.637229  17.339319  -14.006736
# 6374  lag_phase-sta_phase  A7VA03_BACUC  1.542062  18.080021   11.845481
# 6664  lag_phase-sta_phase  A7V6D6_BACUC -1.726231  20.318960   -7.983543
# 6787  lag_phase-sta_phase  A7V7E4_BACUC  1.893062  17.786896    6.449819
#
#            P.Value     adj.P.Val          B  hit          Gene  \
# ...

# %%
S3422 = pd.read_csv('S3422_LM10E_analysis_result.csv', sep=',').drop('Unnamed: 0', axis=1)
S3422[(abs(S3422.logFC) > 1.5) & (S3422['adj.P.Val'] < 0.05) & (S3422.comparison=='DMSO-Met')]
# Out:
#      comparison    Entry.Name     logFC    AveExpr          t       P.Value  \
# 2392   DMSO-Met  A7V2Z3_BACUC -1.892146  29.850087 -54.928142  2.568645e-14
# 2395   DMSO-Met  A7UY08_BACUC -2.298004  25.077737 -48.178662  1.019856e-13
# 2398   DMSO-Met  A7V700_BACUC  2.514702  19.546447  43.567471  2.935020e-13
# 2406   DMSO-Met  A7V6P1_BACUC  1.600867  23.743733  34.048214  3.893649e-12
# 2452   DMSO-Met  A7V182_BACUC  1.905118  18.777805  23.729904  1.680350e-10
# 2483   DMSO-Met  A7V072_BACUC  1.704975  18.684197  20.835707  6.458900e-10
# 2509   DMSO-Met  A7UZJ9_BACUC -2.247049  22.635896 -19.535650  1.254964e-09
# 2669   DMSO-Met  A7V6Z8_BACUC  2.299863  23.806258  12.967666  8.058663e-08
#
#          adj.P.Val          B  hit          Gene  \
# 2392  2.623850e-11  23.431711  hit  BACUNI_01935
# 2395  4.876949e-11  22.142108  hit  BACUNI_00179
# 2398  8.104250e-11  21.122951  hit  BACUNI_03364
# 2406  5.818572e-10  18.542850  hit  BACUNI_03254
# ...
